# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.interpolate import make_interp_spline

# %%
#import data from FAO of the United Nations
FAO = pd.read_csv('FAOSTAT_1.csv')
FAO
# Out:
#      Domain Code Domain  Area Code (FAO)                      Area  \
# 0             QC  Crops               10                 Australia
# 1             QC  Crops               10                 Australia
# 2             QC  Crops               10                 Australia
# 3             QC  Crops               10                 Australia
# 4             QC  Crops               10                 Australia
# ...          ...    ...              ...                       ...
# 3535          QC  Crops              231  United States of America
# 3536          QC  Crops              231  United States of America
# 3537          QC  Crops              231  United States of America
# 3538          QC  Crops              231  United States of America
# 3539          QC  Crops              231  United States of America
#
#       Element Code         Element  Item Code (FAO)         Item  Year Code  \
# 0             5312  Area harvested              108  Cereals nes       1961
# ...

# %%
FAO.shape
# Out:
# (3540, 14)

# %%
F = FAO.loc[:, ["Area", "Element", "Item", "Year", "Value", "Unit"]]
F
# Out:
#                           Area         Element         Item  Year       Value  \
# 0                    Australia  Area harvested  Cereals nes  1961         NaN
# 1                    Australia  Area harvested  Cereals nes  1962         NaN
# 2                    Australia  Area harvested  Cereals nes  1963         NaN
# 3                    Australia  Area harvested  Cereals nes  1964         NaN
# 4                    Australia  Area harvested  Cereals nes  1965         NaN
# ...                        ...             ...          ...   ...         ...
# 3535  United States of America      Production        Wheat  2015  55839540.0
# 3536  United States of America      Production        Wheat  2016  62831507.0
# 3537  United States of America      Production        Wheat  2017  47379810.0
# 3538  United States of America      Production        Wheat  2018  51305540.0
# 3539  United States of America      Production        Wheat  2019  52257620.0
#
#         Unit
# 0        NaN
# ...

# %%
P =  F[F. Element == 'Production']
P
# Out:
#                           Area     Element         Item  Year       Value  \
# 118                  Australia  Production  Cereals nes  1961         NaN
# 119                  Australia  Production  Cereals nes  1962         NaN
# 120                  Australia  Production  Cereals nes  1963         NaN
# 121                  Australia  Production  Cereals nes  1964         NaN
# 122                  Australia  Production  Cereals nes  1965         NaN
# ...                        ...         ...          ...   ...         ...
# 3535  United States of America  Production        Wheat  2015  55839540.0
# 3536  United States of America  Production        Wheat  2016  62831507.0
# 3537  United States of America  Production        Wheat  2017  47379810.0
# 3538  United States of America  Production        Wheat  2018  51305540.0
# 3539  United States of America  Production        Wheat  2019  52257620.0
#
#         Unit
# 118      NaN
# 119      NaN
# 120      NaN
# 121      NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37442a119fed> in <module>
# ----> 1 pd.merge(FAO,F,P)
#
# NameError: name 'pd' is not defined

# %%
#production quantity in Australia.
AP = P[P. Area == 'Australia']

#Wheat
A1 = AP[AP. Item == 'Wheat']
year = A1['Year']
value = A1['Value']
plt.scatter(year, value, color = 'green')
plt.yscale('log')
plt.xlabel('Wheat production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Rice, peddy
A2 = AP[AP. Item == 'Rice, paddy']
year = A2['Year']
value = A2['Value']
plt.scatter(year, value, color = 'pink')
plt.yscale('log')
plt.xlabel('Rice, peddy production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Maize
A3 = AP[AP. Item == 'Maize']
year = A3['Year']
value = A3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('Maize production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Millet
A4 = AP[AP. Item == 'Millet']
year = A4['Year']
value = A4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('Millet production')
plt.ylabel('Value of production in tonnes')
plt.show()

# %%
#production quantity in China.
CP = P[P. Area == 'China']

#Cereal nes
C0 = CP[CP. Item == 'Cereals nes']
year = C0['Year']
value = C0['Value']
plt.scatter(year, value, color = 'green')
plt.yscale('log')
plt.xlabel('Cereals nes production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Wheat
C1 = CP[CP. Item == 'Wheat']
year = C1['Year']
value = C1['Value']
plt.scatter(year, value, color = 'orange')
plt.yscale('log')
plt.xlabel('Wheat production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Rice, peddy
C2 = CP[CP. Item == 'Rice, paddy']
year = C2['Year']
value = C2['Value']
plt.scatter(year, value, color = 'silver')
plt.yscale('log')
plt.xlabel('Rice, peddy production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Maize
C3 = CP[CP. Item == 'Maize']
year = C3['Year']
value = C3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('Maize production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Millet
C4 = CP[CP. Item == 'Millet']
year = C4['Year']
value = C4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('Millet production')
plt.ylabel('Value of production in tonnes')
plt.show()

# %%
#production quantity in China.
SP = P[P. Area == 'South Africa']

#Cereal nes
S0 = SP[SP. Item == 'Cereals nes']
year = S0['Year']
value = S0['Value']
plt.scatter(year, value, color = 'green')
plt.yscale('log')
plt.xlabel('Cereals nes production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Wheat
S1 = SP[SP. Item == 'Wheat']
year = S1['Year']
value = S1['Value']
plt.scatter(year, value, color = 'purple')
plt.yscale('log')
plt.xlabel('Wheat production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Rice, peddy
S2 = SP[SP. Item == 'Rice, paddy']
year = S2['Year']
value = S2['Value']
plt.scatter(year, value, color = 'silver')
plt.yscale('log')
plt.xlabel('Rice, peddy production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Maize
S3 = SP[SP. Item == 'Maize']
year = S3['Year']
value = S3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('Maize production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Millet
S4 = SP[SP. Item == 'Millet']
year = S4['Year']
value = S4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('Millet production')
plt.ylabel('Value of production in tonnes')
plt.show()

# %%
#production quantity in United States Of America.
UP = P[P. Area == 'United States of America']


#Wheat
UP1 = UP[UP. Item == 'Wheat']
year = UP1['Year']
value = UP1['Value']
plt.scatter(year, value, color = 'purple')
plt.yscale('log')
plt.xlabel('Wheat production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Rice, peddy
UP2 = UP[UP. Item == 'Rice, paddy']
year = UP2['Year']
value = UP2['Value']
plt.scatter(year, value, color = 'silver')
plt.yscale('log')
plt.xlabel('Rice, peddy production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Maize
UP3 = UP[UP. Item == 'Maize']
year = UP3['Year']
value = UP3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('Maize production')
plt.ylabel('Value of production in tonnes')
plt.show()

#Millet
UP4 = UP[UP. Item == 'Millet']
year = UP4['Year']
value = UP4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('Millet production')
plt.ylabel('Value of production in tonnes')
plt.show()

# %%
FAO1 = pd.read_csv('FAOSTAT_2.csv')
FAO1
# Out:
#     Domain Code Domain  Area Code (FAO)                      Area  \
# 0            SC  Crops               10                 Australia
# 1            SC  Crops               10                 Australia
# 2            SC  Crops               10                 Australia
# 3            SC  Crops               10                 Australia
# 4            SC  Crops               10                 Australia
# ..          ...    ...              ...                       ...
# 145          SC  Crops              231  United States of America
# 146          SC  Crops              231  United States of America
# 147          SC  Crops              231  United States of America
# 148          SC  Crops              231  United States of America
# 149          SC  Crops              231  United States of America
#
#      Element Code          Element  Item Code (CPC)         Item  Year Code  \
# 0            5910  Export Quantity           1199.9  Cereals nes       2014
# ...

# %%
#import 2nd dataset from FAO
PD =FAO1.loc[:, ["Area", "Element", "Item", "Year", "Value", "Unit"]]
PD[PD. Element == 'Export Quantity']
# Out:
#                          Area          Element         Item  Year       Value  \
# 0                   Australia  Export Quantity  Cereals nes  2014       226.0
# 1                   Australia  Export Quantity  Cereals nes  2015       664.0
# 2                   Australia  Export Quantity  Cereals nes  2016       168.0
# 3                   Australia  Export Quantity  Cereals nes  2017      1435.0
# 4                   Australia  Export Quantity  Cereals nes  2018        90.0
# ..                        ...              ...          ...   ...         ...
# 140  United States of America  Export Quantity        Wheat  2014  25645749.0
# 141  United States of America  Export Quantity        Wheat  2015  21268696.0
# 142  United States of America  Export Quantity        Wheat  2016  24041586.0
# 143  United States of America  Export Quantity        Wheat  2017  27299214.0
# 144  United States of America  Export Quantity        Wheat  2018  22499006.0
#
#        Unit
# 0    tonnes
# ...

# %%
APD = FAO1[FAO1.Area =='Australia']
APD1= APD[APD.Element == 'Loss']

#Rice, paddy
APD2 = APD1[APD1.Item == 'Rice, paddy']
x = APD2['Year']
y = APD2['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Rice, paddy loss')
plt.show()

#Maize
APD3 = APD1[APD1.Item == 'Maize']
x = APD3['Year']
y = APD3['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Maize loss')
plt.show()

#Millet
APD4 = APD1[APD1.Item == 'Millet']
x = APD4['Year']
y = APD4['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Millet loss')
plt.show()

#Wheat
APD5 = APD1[APD1.Item == 'Wheat']
x = APD5['Year']
y = APD5['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Wheat loss')
plt.show()

# %%
SPD =FAO1[FAO1.Area =='South Africa']
SPD1= SPD[SPD.Element == 'Loss']

#Cereals nes
SPD0 = SPD1[SPD1.Item == 'Cereals nes']
x = SPD0['Year']
y = SPD0['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Cereal nes loss')
plt.show()

#Rice, paddy
SPD2 = SPD1[SPD1.Item == 'Rice, paddy']
x = SPD2['Year']
y = SPD2['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Rice, paddy loss')
plt.show()

#Maize
SPD3 = SPD1[SPD1.Item == 'Maize']
x = SPD3['Year']
y = SPD3['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Maize loss')
plt.show()

#Millet
SPD4 = SPD1[SPD1.Item == 'Millet']
x = SPD4['Year']
y = SPD4['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Millet loss')
plt.show()

#Wheat
SPD5 = SPD1[SPD1.Item == 'Wheat']
x = SPD5['Year']
y = SPD5['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Wheat loss')
plt.show()

# %%
UPD = FAO1[FAO1.Area =='United States of America']
UPD1= UPD[UPD.Element == 'Loss']



#Rice, paddy
UPD2 = UPD1[UPD1.Item == 'Rice, paddy']
x = UPD2['Year']
y = UPD2['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Rice, paddy loss')
plt.show()

#Maize
UPD3 = UPD1[UPD1.Item == 'Maize']
x = UPD3['Year']
y = UPD3['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Maize loss')
plt.show()

#Millet
UPD4 = UPD1[UPD1.Item == 'Millet']
x = UPD4['Year']
y = UPD4['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Millet loss')
plt.show()

#Wheat
UPD5 = UPD1[UPD1.Item == 'Wheat']
x = UPD5['Year']
y = UPD5['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('LOSS VALUE IN tonnes')
plt.title('Wheat loss')
plt.show()

# %%
PD =FAO1.loc[:, ["Area", "Element", "Item", "Year", "Value", "Unit"]]
PV= PD[PD. Element == 'Export Quantity']
PV
# Out:
#                          Area          Element         Item  Year       Value  \
# 0                   Australia  Export Quantity  Cereals nes  2014       226.0
# 1                   Australia  Export Quantity  Cereals nes  2015       664.0
# 2                   Australia  Export Quantity  Cereals nes  2016       168.0
# 3                   Australia  Export Quantity  Cereals nes  2017      1435.0
# 4                   Australia  Export Quantity  Cereals nes  2018        90.0
# ..                        ...              ...          ...   ...         ...
# 140  United States of America  Export Quantity        Wheat  2014  25645749.0
# 141  United States of America  Export Quantity        Wheat  2015  21268696.0
# 142  United States of America  Export Quantity        Wheat  2016  24041586.0
# 143  United States of America  Export Quantity        Wheat  2017  27299214.0
# 144  United States of America  Export Quantity        Wheat  2018  22499006.0
#
#        Unit
# 0    tonnes
# ...

# %%
APV1 = PV[PV.Area =='Australia']

#Rice, paddy
APV2 = APV1[APV1.Item == 'Rice, paddy']
year = APV2['Year']
value = APV2['Value']
plt.plot(year, value)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Rice, paddy EXPORT')
plt.show()

#Maize
APV3 = APV1[APV1.Item == 'Maize']
x = APV3['Year']
y = APV3['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Maize EXPORT')
plt.show()

#Millet
APV4 = APV1[APV1.Item == 'Millet']
x = APV4['Year']
y = APV4['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Millet EXPORT')
plt.show()

#Wheat
APV5 = APV1[APV1.Item == 'Wheat']
x = APV5['Year']
y = APV5['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Wheat EXPORT')
plt.show()

# %%
SPV1 = PV[PV.Area =='South Africa']


#Cereals nes
SPV0 = SPV1[SPV1.Item == 'Cereals nes']
x = SPV0['Year']
y = SPV0['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Cereal nes EXPORT ')
plt.show()

#Rice, paddy
SPV2 = SPV1[SPV1.Item == 'Rice, paddy']
x = SPV2['Year']
y = SPV2['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Rice, paddy EXPORT')
plt.show()

#Maize
SPV3 = SPV1[SPV1.Item == 'Maize']
x = SPV3['Year']
y = SPV3['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel(' tonnes')
plt.title('Maize EXPORT')
plt.show()

#Millet
SPV4 = SPV1[SPV1.Item == 'Millet']
x = SPV4['Year']
y = SPV4['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Millet EXPORT')
plt.show()

#Wheat
SPV5 = SPV1[SPV1.Item == 'Wheat']
x = SPV5['Year']
y = SPV5['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Wheat EXPORT')
plt.show()

# %%
UPV1 = PV[PV.Area =='United States of America']

#Rice, paddy
UPV2 = UPV1[UPV1.Item == 'Rice, paddy']
x = UPV2['Year']
y = UPV2['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel(' tonnes')
plt.title('Rice, paddy ')
plt.show()

#Maize
UPV3 = UPV1[UPV1.Item == 'Maize']
x = UPV3['Year']
y = UPV3['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Maize ')
plt.show()

#Millet
UPV4 = UPV1[UPV1.Item == 'Millet']
x = UPV4['Year']
y = UPV4['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel(' tonnes')
plt.title('Millet ')
plt.show()

#Wheat
UPV5 = UPV1[UPV1.Item == 'Wheat']
x = UPV5['Year']
y = UPV5['Value']
xnew = np.linspace(x.min(), x.max(), 300)
gfg = make_interp_spline(x, y)
y_new = gfg(xnew)
plt.plot(xnew, y_new)
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('tonnes')
plt.title('Wheat ')
plt.show()

# %%
PP = pd.read_csv('FAOSTAT_3.csv')
PPV =PP.loc[:, ["Area", "Element", "Item", "Year", "Value", "Unit"]]
PPV
# Out:
#                          Area                     Element         Item  Year  \
# 0                   Australia  Producer Price (USD/tonne)  Cereals nes  1991
# 1                   Australia  Producer Price (USD/tonne)        Maize  1991
# 2                   Australia  Producer Price (USD/tonne)       Millet  1991
# 3                   Australia  Producer Price (USD/tonne)  Rice, paddy  1991
# 4                   Australia  Producer Price (USD/tonne)        Wheat  1991
# ..                        ...                         ...          ...   ...
# 575  United States of America  Producer Price (USD/tonne)  Cereals nes  2019
# 576  United States of America  Producer Price (USD/tonne)        Maize  2019
# 577  United States of America  Producer Price (USD/tonne)       Millet  2019
# 578  United States of America  Producer Price (USD/tonne)  Rice, paddy  2019
# 579  United States of America  Producer Price (USD/tonne)        Wheat  2019
#
#      Value Unit
# 0      NaN  NaN
# ...

# %%
APPV = PPV[PPV.Area =='Australia']

#Wheat
APPV1 = APPV[APPV. Item == 'Wheat']
year = APPV1['Year']
value = APPV1['Value']
plt.scatter(year, value, color = 'purple')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Wheat')
plt.show()

#Rice, peddy
APPV2 = APPV[APPV. Item == 'Rice, paddy']
year = APPV2['Year']
value = APPV2['Value']
plt.scatter(year, value, color = 'silver')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Rice, paddy ')
plt.show()

#Maize
APPV3 = APPV[APPV. Item == 'Maize']
year = APPV3['Year']
value = APPV3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Maize ')
plt.show()

#Millet
APPV4 = APPV[APPV. Item == 'Millet']
year = APPV4['Year']
value = APPV4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Millet ')
plt.show()

# %%
CPPV = PPV[PPV.Area =='China']


#Wheat
CPPV1 = CPPV[CPPV. Item == 'Wheat']
year = CPPV1['Year']
value = CPPV1['Value']
plt.scatter(year, value, color = 'purple')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Wheat')
plt.show()

#Rice, peddy
CPPV2 = CPPV[CPPV. Item == 'Rice, paddy']
year = CPPV2['Year']
value = CPPV2['Value']
plt.scatter(year, value, color = 'silver')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Rice, paddy ')
plt.show()

#Maize
CPPV3 = CPPV[CPPV. Item == 'Maize']
year = CPPV3['Year']
value = CPPV3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Maize ')
plt.show()

#Millet
CPPV4 = CPPV[CPPV. Item == 'Millet']
year = CPPV4['Year']
value = CPPV4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Millet')
plt.show()

# %%
SPPV = PPV[PPV.Area =='South Africa']


#Wheat
SPPV1 = SPPV[SPPV. Item == 'Wheat']
year = SPPV1['Year']
value = SPPV1['Value']
plt.scatter(year, value, color = 'purple')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Wheat')
plt.show()


#Maize
SPPV3 = SPPV[SPPV. Item == 'Maize']
year = SPPV3['Year']
value = SPPV3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Maize ')
plt.show()

# %%
UPPV = PPV[PPV.Area =='United States of America']

#Wheat
UPPV1 = UPPV[UPPV. Item == 'Wheat']
year = UPPV1['Year']
value = UPPV1['Value']
plt.scatter(year, value, color = 'purple')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Wheat')
plt.show()

#Rice, peddy
UPPV2 = UPPV[UPPV. Item == 'Rice, paddy']
year = UPPV2['Year']
value = UPPV2['Value']
plt.scatter(year, value, color = 'silver')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Rice, paddy')
plt.show()

#Maize
UPPV3 = UPPV[UPPV. Item == 'Maize']
year = UPPV3['Year']
value = UPPV3['Value']
plt.scatter(year, value, color = 'red')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Maize ')
plt.show()

#Millet
UPPV4 = UPPV[UPPV. Item == 'Millet']
year = UPPV4['Year']
value = UPPV4['Value']
plt.scatter(year, value, color = 'blue')
plt.yscale('log')
plt.xlabel('YEAR')
plt.ylabel('USD $')
plt.title('Millet ')
plt.show()
